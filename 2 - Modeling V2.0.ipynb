# %% [markdown]
# # Instagram Like Prediction @310ai Competition - Modeling, Visualization & Evaluation
#
# This notebook is a continuation of ***Data*** notebook. In this part of project we will train the predictive model, analyze it, visualize its output and evaluate it. The reason for this separation, is to make the notebooks easier to understand and less dependent on each other, especially for this case since the Instagram showed that it reguralry changing its api and bot mitigation methods. Multiple stages of this project have checkpoints, thus the notebook will run without issues.
#
# As we pointed out in the previous notebook, we will use **XGBoost 1.7** as the algorithm. So let's without further ado, dive into it.

# %%
import pandas as pd
pd.options.display.float_format = '{:,.2f}'.format
import numpy as np
import xgboost as xgb
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import GridSearchCV
sns.set_theme(style='darkgrid')

# %% [markdown]
# First thing first, we must load the data, also we have some identifying features, called shortcode, username and id, which will not affect the accuracy of the model, thus we can drop these features all together.
#
# Also we have to remove the comment feature, although this feature has a high importance, but since we won't know how an unpulished post will perform comment-wise, we can't estimate this value (this feature is like the Like feature, can be a dependent variable in another approach), thus we have to remove it from the dataset.

# %%
df = pd.read_csv('Data/main v3.0.csv')
df.drop(columns=['Unnamed: 0', 'shortcode', 'username', 'id', 'comment'], inplace=True)
df.head()
# Out:
#       post_type    like    category_name   follower  following  ar_effect  \
# 0  GraphSidecar  390465  Digital creator  633916664         59       True
# 1  GraphSidecar  320587  Digital creator  633916664         59       True
# 2  GraphSidecar  480033  Digital creator  633916664         59       True
# 3  GraphSidecar  351673  Digital creator  633916664         59       True
# 4    GraphImage  273314  Digital creator  633916664         59       True
#
#    type_business  type_professional  verified  reel_count  reel_avg_view  \
# 0          False               True      True        1256   9,409,868.50
# 1          False               True      True        1256   9,409,868.50
# 2          False               True      True        1256   9,409,868.50
# 3          False               True      True        1256   9,409,868.50
# 4          False               True      True        1256   9,409,868.50
#
#    reel_avg_comment  reel_avg_like  reel_avg_duration  reel_frequency  \
# 0         13,527.08     572,818.75              92.47           18.55
# 1         13,527.08     572,818.75              92.47           18.55
# 2         13,527.08     572,818.75              92.47           18.55
# 3         13,527.08     572,818.75              92.47           18.55
# 4         13,527.08     572,818.75              92.47           18.55
#
#    media_count  media_avg_comment  media_avg_like  media_frequency  \
# 0         7408           8,552.00      473,666.50             1.19
# 1         7408           8,552.00      473,666.50             1.19
# 2         7408           8,552.00      473,666.50             1.19
# 3         7408           8,552.00      473,666.50             1.19
# 4         7408           8,552.00      473,666.50             1.19
#
#                         object
# 0               pot, flowerpot
# 1  rock_crab, Cancer_irroratus
# 2             feather_boa, boa
# 3            teddy, teddy_bear
# 4                          wig

# %% [markdown]
# Now we can separate independent and dependent variables. Usually we cal independent variables X and dependent variables y.

# %%
# remove objects from instagram detection algorithm and only use efficient net algorithm
exclude_columns = [
    'like',
]
X, y = df.loc[:, ~df.columns.isin(exclude_columns)].copy(), df[['like']].copy()

# %% [markdown]
# As we said in the previous notebook, XGBoost since the version of 1.7 is capable of working with categorical variables, but before casting the categorical variables through the model, we must change the type of those features to `categorical` in pandas.

# %%
categorical_features = X.select_dtypes(exclude=np.number).columns.tolist()
for feature in categorical_features:
    X[feature] = X[feature].astype('category')

# %% [markdown]
# Now we can split the data into training and validation. We will use the 25% of data as validation set.

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=69)

# %% [markdown]
# ### What architecture and pre trained models -if any- you used?
#
# - For the object detection in images I have used a pre trained model called `EfficientNet b7`, This model is trained on the ImageNet-1k (capable of detecting 1000 objects in images.)
# - For predicting the amount of likes (regression) I have used XGBoost Regressor model, from XGBoost version 1.7.

# %% [markdown]
# ### What hardware and cloud you used?
#
# I have used a very basic and standard hardware, although the xgboost library can work with cuda and graphic cards to train the model, but I trained it on the CPU since the majority of time I have access to a PC without a Graphic Card. I have coded this competition in my free time in the ATU office. Due to some complications and geo-restrictions, I chose not to use the cloud.

# %% [markdown]
# ### Training Hyperparameters
# I have used these hyperparameters for the model. These hyperparameters were tuned with grid searching among their standard values and the values resulting in the most accuracy were selected:
# - ***tree method***: <u>hist</u>; It runs sketching before training using only user provided weights instead of hessian. The subsequent per-node histogram is built upon this global sketch. This is the fastest algorithm as it runs sketching only once. [Reference](https://xgboost.readthedocs.io/en/stable/treemethod.html)
# - ***booster***: <u>dart</u>; Which booster to use.
# - ***subsample***:  <u>0.8</u>; Subsample ratio of the training instances. Setting it to 0.5 means that XGBoost would randomly sample half of the training data prior to growing trees. and this will prevent overfitting. Subsampling will occur once in every boosting iteration [Reference](https://xgboost.readthedocs.io/en/stable/parameter.html)
# - ***max_depth***: <u>16</u>; Maximum depth of a tree. Increasing this value will make the model more complex and more likely to overfit. 0 indicates no limit on depth. Beware that XGBoost aggressively consumes memory when training a deep tree. [Reference](https://xgboost.readthedocs.io/en/stable/parameter.html)
# - ***reg_lambda***: <u>0.5</u>; L2 regularization term on weights. Increasing this value will make model more conservative. [Reference](https://xgboost.readthedocs.io/en/stable/parameter.html)
#
# #### Hyperparameter Tunning
# In this cell we will define hyperparameters value for model. Have in mind that since we will perform a cross-validation, parameters are actually list of parameters to find the best one among their combination.

# %%
model = xgb.XGBRegressor(tree_method='hist', enable_categorical=True)

params = {
    'booster': ['gbtree', 'dart'],
    'eta': [0.1, 0.05, 0.01],
    'subsample': [.8, .9, .1],
    'max_depth': np.arange(14, 17),
    'reg_lambda': np.arange(0.5, 1.25, 0.25),
}

grid = GridSearchCV(model, param_grid=params, return_train_score=True, cv=5, verbose=3)
grid.fit(X, y)
# Out:
# Fitting 5 folds for each of 162 candidates, totalling 810 fits
# [CV 1/5] END booster=gbtree, eta=0.1, max_depth=14, reg_lambda=0.5, subsample=0.8;, score=(train=1.000, test=0.269) total time=   2.6s
# [CV 2/5] END booster=gbtree, eta=0.1, max_depth=14, reg_lambda=0.5, subsample=0.8;, score=(train=1.000, test=0.443) total time=   2.2s
# [CV 3/5] END booster=gbtree, eta=0.1, max_depth=14, reg_lambda=0.5, subsample=0.8;, score=(train=1.000, test=0.458) total time=   2.3s
# [CV 4/5] END booster=gbtree, eta=0.1, max_depth=14, reg_lambda=0.5, subsample=0.8;, score=(train=1.000, test=0.514) total time=   2.7s
# [CV 5/5] END booster=gbtree, eta=0.1, max_depth=14, reg_lambda=0.5, subsample=0.8;, score=(train=1.000, test=0.448) total time=   3.4s
# [CV 1/5] END booster=gbtree, eta=0.1, max_depth=14, reg_lambda=0.5, subsample=0.9;, score=(train=1.000, test=0.306) total time=   3.8s
# [CV 2/5] END booster=gbtree, eta=0.1, max_depth=14, reg_lambda=0.5, subsample=0.9;, score=(train=1.000, test=0.420) total time=   2.3s
# [CV 3/5] END booster=gbtree, eta=0.1, max_depth=14, reg_lambda=0.5, subsample=0.9;, score=(train=1.000, test=0.403) total time=   3.0s
# [CV 4/5] END booster=gbtree, eta=0.1, max_depth=14, reg_lambda=0.5, subsample=0.9;, score=(train=1.000, test=0.505) total time=   2.6s
# [CV 5/5] END booster=gbtree, eta=0.1, max_depth=14, reg_lambda=0.5, subsample=0.9;, score=(train=1.000, test=0.491) total time=   2.8s
# [CV 1/5] END booster=gbtree, eta=0.1, max_depth=14, reg_lambda=0.5, subsample=1;, score=(train=1.000, test=0.334) total time=   2.8s
# [CV 2/5] END booster=gbtree, eta=0.1, max_depth=14, reg_lambda=0.5, subsample=1;, score=(train=1.000, test=0.381) total time=   2.9s
# [CV 3/5] END booster=gbtree, eta=0.1, max_depth=14, reg_lambda=0.5, subsample=1;, score=(train=1.000, test=0.411) total time=   3.9s
# [CV 4/5] END booster=gbtree, eta=0.1, max_depth=14, reg_lambda=0.5, subsample=1;, score=(train=1.000, test=0.509) total time=   4.6s
# [CV 5/5] END booster=gbtree, eta=0.1, max_depth=14, reg_lambda=0.5, subsample=1;, score=(train=1.000, test=0.458) total time=   2.8s
# [CV 1/5] END booster=gbtree, eta=0.1, max_depth=14, reg_lambda=0.75, subsample=0.8;, score=(train=1.000, test=0.307) total time=   2.4s
# [CV 2/5] END booster=gbtree, eta=0.1, max_depth=14, reg_lambda=0.75, subsample=0.8;, score=(train=1.000, test=0.426) total time=   2.0s
# [CV 3/5] END booster=gbtree, eta=0.1, max_depth=14, reg_lambda=0.75, subsample=0.8;, score=(train=1.000, test=0.452) total time=   1.8s
# [CV 4/5] END booster=gbtree, eta=0.1, max_depth=14, reg_lambda=0.75, subsample=0.8;, score=(train=1.000, test=0.518) total time=   2.0s
# [CV 5/5] END booster=gbtree, eta=0.1, max_depth=14, reg_lambda=0.75, subsample=0.8;, score=(train=1.000, test=0.439) total time=   2.0s
# [CV 1/5] END booster=gbtree, eta=0.1, max_depth=14, reg_lambda=0.75, subsample=0.9;, score=(train=1.000, test=0.269) total time=   2.3s
# [CV 2/5] END booster=gbtree, eta=0.1, max_depth=14, reg_lambda=0.75, subsample=0.9;, score=(train=1.000, test=0.397) total time=   1.9s
# [CV 3/5] END booster=gbtree, eta=0.1, max_depth=14, reg_lambda=0.75, subsample=0.9;, score=(train=1.000, test=0.401) total time=   2.0s
# [CV 4/5] END booster=gbtree, eta=0.1, max_depth=14, reg_lambda=0.75, subsample=0.9;, score=(train=1.000, test=0.580) total time=   2.5s
# [CV 5/5] END booster=gbtree, eta=0.1, max_depth=14, reg_lambda=0.75, subsample=0.9;, score=(train=1.000, test=0.504) total time=   2.4s
# [CV 1/5] END booster=gbtree, eta=0.1, max_depth=14, reg_lambda=0.75, subsample=1;, score=(train=1.000, test=0.324) total time=   2.8s
# [CV 2/5] END booster=gbtree, eta=0.1, max_depth=14, reg_lambda=0.75, subsample=1;, score=(train=1.000, test=0.408) total time=   2.2s
# [CV 3/5] END booster=gbtree, eta=0.1, max_depth=14, reg_lambda=0.75, subsample=1;, score=(train=1.000, test=0.404) total time=   2.9s
# [CV 4/5] END booster=gbtree, eta=0.1, max_depth=14, reg_lambda=0.75, subsample=1;, score=(train=1.000, test=0.500) total time=   3.6s
# [CV 5/5] END booster=gbtree, eta=0.1, max_depth=14, reg_lambda=0.75, subsample=1;, score=(train=1.000, test=0.497) total time=   3.3s
# [CV 1/5] END booster=gbtree, eta=0.1, max_depth=14, reg_lambda=1.0, subsample=0.8;, score=(train=1.000, test=0.211) total time=   2.2s
# [CV 2/5] END booster=gbtree, eta=0.1, max_depth=14, reg_lambda=1.0, subsample=0.8;, score=(train=1.000, test=0.439) total time=   1.7s
# [CV 3/5] END booster=gbtree, eta=0.1, max_depth=14, reg_lambda=1.0, subsample=0.8;, score=(train=1.000, test=0.451) total time=   1.6s
# [CV 4/5] END booster=gbtree, eta=0.1, max_depth=14, reg_lambda=1.0, subsample=0.8;, score=(train=1.000, test=0.490) total time=   2.1s
# [CV 5/5] END booster=gbtree, eta=0.1, max_depth=14, reg_lambda=1.0, subsample=0.8;, score=(train=1.000, test=0.455) total time=   1.8s
# [CV 1/5] END booster=gbtree, eta=0.1, max_depth=14, reg_lambda=1.0, subsample=0.9;, score=(train=1.000, test=0.258) total time=   1.8s
# [CV 2/5] END booster=gbtree, eta=0.1, max_depth=14, reg_lambda=1.0, subsample=0.9;, score=(train=1.000, test=0.394) total time=   1.7s
# [CV 3/5] END booster=gbtree, eta=0.1, max_depth=14, reg_lambda=1.0, subsample=0.9;, score=(train=1.000, test=0.405) total time=   1.9s
# [CV 4/5] END booster=gbtree, eta=0.1, max_depth=14, reg_lambda=1.0, subsample=0.9;, score=(train=1.000, test=0.538) total time=   2.3s
# [CV 5/5] END booster=gbtree, eta=0.1, max_depth=14, reg_lambda=1.0, subsample=0.9;, score=(train=1.000, test=0.477) total time=   2.0s
# [CV 1/5] END booster=gbtree, eta=0.1, max_depth=14, reg_lambda=1.0, subsample=1;, score=(train=1.000, test=0.276) total time=   2.3s
# [CV 2/5] END booster=gbtree, eta=0.1, max_depth=14, reg_lambda=1.0, subsample=1;, score=(train=1.000, test=0.356) total time=   2.0s
# [CV 3/5] END booster=gbtree, eta=0.1, max_depth=14, reg_lambda=1.0, subsample=1;, score=(train=1.000, test=0.429) total time=   2.7s
# [CV 4/5] END booster=gbtree, eta=0.1, max_depth=14, reg_lambda=1.0, subsample=1;, score=(train=1.000, test=0.520) total time=   2.4s
# [CV 5/5] END booster=gbtree, eta=0.1, max_depth=14, reg_lambda=1.0, subsample=1;, score=(train=1.000, test=0.421) total time=   2.6s
# [CV 1/5] END booster=gbtree, eta=0.1, max_depth=15, reg_lambda=0.5, subsample=0.8;, score=(train=1.000, test=0.271) total time=   1.8s
# [CV 2/5] END booster=gbtree, eta=0.1, max_depth=15, reg_lambda=0.5, subsample=0.8;, score=(train=1.000, test=0.440) total time=   2.5s
# [CV 3/5] END booster=gbtree, eta=0.1, max_depth=15, reg_lambda=0.5, subsample=0.8;, score=(train=1.000, test=0.460) total time=   2.4s
# [CV 4/5] END booster=gbtree, eta=0.1, max_depth=15, reg_lambda=0.5, subsample=0.8;, score=(train=1.000, test=0.535) total time=   2.7s
# [CV 5/5] END booster=gbtree, eta=0.1, max_depth=15, reg_lambda=0.5, subsample=0.8;, score=(train=1.000, test=0.460) total time=   2.1s
# [CV 1/5] END booster=gbtree, eta=0.1, max_depth=15, reg_lambda=0.5, subsample=0.9;, score=(train=1.000, test=0.305) total time=   4.2s
# [CV 2/5] END booster=gbtree, eta=0.1, max_depth=15, reg_lambda=0.5, subsample=0.9;, score=(train=1.000, test=0.421) total time=   2.1s
# [CV 3/5] END booster=gbtree, eta=0.1, max_depth=15, reg_lambda=0.5, subsample=0.9;, score=(train=1.000, test=0.397) total time=   2.6s
# [CV 4/5] END booster=gbtree, eta=0.1, max_depth=15, reg_lambda=0.5, subsample=0.9;, score=(train=1.000, test=0.509) total time=   2.4s
# [CV 5/5] END booster=gbtree, eta=0.1, max_depth=15, reg_lambda=0.5, subsample=0.9;, score=(train=1.000, test=0.502) total time=   2.9s
# [CV 1/5] END booster=gbtree, eta=0.1, max_depth=15, reg_lambda=0.5, subsample=1;, score=(train=1.000, test=0.338) total time=   3.1s
# [CV 2/5] END booster=gbtree, eta=0.1, max_depth=15, reg_lambda=0.5, subsample=1;, score=(train=1.000, test=0.380) total time=   2.9s
# [CV 3/5] END booster=gbtree, eta=0.1, max_depth=15, reg_lambda=0.5, subsample=1;, score=(train=1.000, test=0.413) total time=   2.9s
# [CV 4/5] END booster=gbtree, eta=0.1, max_depth=15, reg_lambda=0.5, subsample=1;, score=(train=1.000, test=0.514) total time=   3.5s
# [CV 5/5] END booster=gbtree, eta=0.1, max_depth=15, reg_lambda=0.5, subsample=1;, score=(train=1.000, test=0.426) total time=   3.5s
# [CV 1/5] END booster=gbtree, eta=0.1, max_depth=15, reg_lambda=0.75, subsample=0.8;, score=(train=1.000, test=0.306) total time=   2.3s
# [CV 2/5] END booster=gbtree, eta=0.1, max_depth=15, reg_lambda=0.75, subsample=0.8;, score=(train=1.000, test=0.426) total time=   2.1s
# [CV 3/5] END booster=gbtree, eta=0.1, max_depth=15, reg_lambda=0.75, subsample=0.8;, score=(train=1.000, test=0.455) total time=   2.5s
# [CV 4/5] END booster=gbtree, eta=0.1, max_depth=15, reg_lambda=0.75, subsample=0.8;, score=(train=1.000, test=0.515) total time=   2.1s
# [CV 5/5] END booster=gbtree, eta=0.1, max_depth=15, reg_lambda=0.75, subsample=0.8;, score=(train=1.000, test=0.428) total time=   2.2s
# [CV 1/5] END booster=gbtree, eta=0.1, max_depth=15, reg_lambda=0.75, subsample=0.9;, score=(train=1.000, test=0.271) total time=   2.1s
# [CV 2/5] END booster=gbtree, eta=0.1, max_depth=15, reg_lambda=0.75, subsample=0.9;, score=(train=1.000, test=0.397) total time=   2.3s
# [CV 3/5] END booster=gbtree, eta=0.1, max_depth=15, reg_lambda=0.75, subsample=0.9;, score=(train=1.000, test=0.407) total time=   2.1s
# [CV 4/5] END booster=gbtree, eta=0.1, max_depth=15, reg_lambda=0.75, subsample=0.9;, score=(train=1.000, test=0.565) total time=   2.7s
# [CV 5/5] END booster=gbtree, eta=0.1, max_depth=15, reg_lambda=0.75, subsample=0.9;, score=(train=1.000, test=0.516) total time=   2.3s
# [CV 1/5] END booster=gbtree, eta=0.1, max_depth=15, reg_lambda=0.75, subsample=1;, score=(train=1.000, test=0.326) total time=   3.0s
# [CV 2/5] END booster=gbtree, eta=0.1, max_depth=15, reg_lambda=0.75, subsample=1;, score=(train=1.000, test=0.408) total time=   2.4s
# [CV 3/5] END booster=gbtree, eta=0.1, max_depth=15, reg_lambda=0.75, subsample=1;, score=(train=1.000, test=0.403) total time=   2.8s
# [CV 4/5] END booster=gbtree, eta=0.1, max_depth=15, reg_lambda=0.75, subsample=1;, score=(train=1.000, test=0.506) total time=   2.8s
# [CV 5/5] END booster=gbtree, eta=0.1, max_depth=15, reg_lambda=0.75, subsample=1;, score=(train=1.000, test=0.488) total time=   2.9s
# [CV 1/5] END booster=gbtree, eta=0.1, max_depth=15, reg_lambda=1.0, subsample=0.8;, score=(train=1.000, test=0.222) total time=   1.7s
# [CV 2/5] END booster=gbtree, eta=0.1, max_depth=15, reg_lambda=1.0, subsample=0.8;, score=(train=1.000, test=0.437) total time=   1.7s
# [CV 3/5] END booster=gbtree, eta=0.1, max_depth=15, reg_lambda=1.0, subsample=0.8;, score=(train=1.000, test=0.459) total time=   1.6s
# [CV 4/5] END booster=gbtree, eta=0.1, max_depth=15, reg_lambda=1.0, subsample=0.8;, score=(train=1.000, test=0.503) total time=   2.4s
# [CV 5/5] END booster=gbtree, eta=0.1, max_depth=15, reg_lambda=1.0, subsample=0.8;, score=(train=1.000, test=0.470) total time=   1.7s
# [CV 1/5] END booster=gbtree, eta=0.1, max_depth=15, reg_lambda=1.0, subsample=0.9;, score=(train=1.000, test=0.255) total time=   2.0s
# [CV 2/5] END booster=gbtree, eta=0.1, max_depth=15, reg_lambda=1.0, subsample=0.9;, score=(train=1.000, test=0.394) total time=   2.0s
# [CV 3/5] END booster=gbtree, eta=0.1, max_depth=15, reg_lambda=1.0, subsample=0.9;, score=(train=1.000, test=0.407) total time=   2.2s
# [CV 4/5] END booster=gbtree, eta=0.1, max_depth=15, reg_lambda=1.0, subsample=0.9;, score=(train=1.000, test=0.540) total time=   2.1s
# [CV 5/5] END booster=gbtree, eta=0.1, max_depth=15, reg_lambda=1.0, subsample=0.9;, score=(train=1.000, test=0.448) total time=   2.4s
# [CV 1/5] END booster=gbtree, eta=0.1, max_depth=15, reg_lambda=1.0, subsample=1;, score=(train=1.000, test=0.283) total time=   3.6s
# [CV 2/5] END booster=gbtree, eta=0.1, max_depth=15, reg_lambda=1.0, subsample=1;, score=(train=1.000, test=0.357) total time=   2.4s
# [CV 3/5] END booster=gbtree, eta=0.1, max_depth=15, reg_lambda=1.0, subsample=1;, score=(train=1.000, test=0.431) total time=   2.6s
# [CV 4/5] END booster=gbtree, eta=0.1, max_depth=15, reg_lambda=1.0, subsample=1;, score=(train=1.000, test=0.516) total time=   2.5s
# [CV 5/5] END booster=gbtree, eta=0.1, max_depth=15, reg_lambda=1.0, subsample=1;, score=(train=1.000, test=0.412) total time=   2.7s
# [CV 1/5] END booster=gbtree, eta=0.1, max_depth=16, reg_lambda=0.5, subsample=0.8;, score=(train=1.000, test=0.269) total time=   2.0s
# [CV 2/5] END booster=gbtree, eta=0.1, max_depth=16, reg_lambda=0.5, subsample=0.8;, score=(train=1.000, test=0.447) total time=   1.9s
# [CV 3/5] END booster=gbtree, eta=0.1, max_depth=16, reg_lambda=0.5, subsample=0.8;, score=(train=1.000, test=0.464) total time=   2.5s
# [CV 4/5] END booster=gbtree, eta=0.1, max_depth=16, reg_lambda=0.5, subsample=0.8;, score=(train=1.000, test=0.521) total time=   2.1s
# [CV 5/5] END booster=gbtree, eta=0.1, max_depth=16, reg_lambda=0.5, subsample=0.8;, score=(train=1.000, test=0.459) total time=   2.6s
# [CV 1/5] END booster=gbtree, eta=0.1, max_depth=16, reg_lambda=0.5, subsample=0.9;, score=(train=1.000, test=0.308) total time=   2.3s
# [CV 2/5] END booster=gbtree, eta=0.1, max_depth=16, reg_lambda=0.5, subsample=0.9;, score=(train=1.000, test=0.420) total time=   2.6s
# [CV 3/5] END booster=gbtree, eta=0.1, max_depth=16, reg_lambda=0.5, subsample=0.9;, score=(train=1.000, test=0.400) total time=   2.5s
# [CV 4/5] END booster=gbtree, eta=0.1, max_depth=16, reg_lambda=0.5, subsample=0.9;, score=(train=1.000, test=0.498) total time=   2.9s
# [CV 5/5] END booster=gbtree, eta=0.1, max_depth=16, reg_lambda=0.5, subsample=0.9;, score=(train=1.000, test=0.504) total time=   2.7s
# [CV 1/5] END booster=gbtree, eta=0.1, max_depth=16, reg_lambda=0.5, subsample=1;, score=(train=1.000, test=0.335) total time=   3.6s
# [CV 2/5] END booster=gbtree, eta=0.1, max_depth=16, reg_lambda=0.5, subsample=1;, score=(train=1.000, test=0.380) total time=   2.9s
# [CV 3/5] END booster=gbtree, eta=0.1, max_depth=16, reg_lambda=0.5, subsample=1;, score=(train=1.000, test=0.413) total time=   3.2s
# [CV 4/5] END booster=gbtree, eta=0.1, max_depth=16, reg_lambda=0.5, subsample=1;, score=(train=1.000, test=0.523) total time=   3.2s
# [CV 5/5] END booster=gbtree, eta=0.1, max_depth=16, reg_lambda=0.5, subsample=1;, score=(train=1.000, test=0.469) total time=   3.5s
# [CV 1/5] END booster=gbtree, eta=0.1, max_depth=16, reg_lambda=0.75, subsample=0.8;, score=(train=1.000, test=0.302) total time=   1.8s
# [CV 2/5] END booster=gbtree, eta=0.1, max_depth=16, reg_lambda=0.75, subsample=0.8;, score=(train=1.000, test=0.422) total time=   1.9s
# [CV 3/5] END booster=gbtree, eta=0.1, max_depth=16, reg_lambda=0.75, subsample=0.8;, score=(train=1.000, test=0.448) total time=   2.0s
# [CV 4/5] END booster=gbtree, eta=0.1, max_depth=16, reg_lambda=0.75, subsample=0.8;, score=(train=1.000, test=0.517) total time=   2.2s
# [CV 5/5] END booster=gbtree, eta=0.1, max_depth=16, reg_lambda=0.75, subsample=0.8;, score=(train=1.000, test=0.461) total time=   2.3s
# [CV 1/5] END booster=gbtree, eta=0.1, max_depth=16, reg_lambda=0.75, subsample=0.9;, score=(train=1.000, test=0.279) total time=   2.2s
# [CV 2/5] END booster=gbtree, eta=0.1, max_depth=16, reg_lambda=0.75, subsample=0.9;, score=(train=1.000, test=0.395) total time=   2.6s
# [CV 3/5] END booster=gbtree, eta=0.1, max_depth=16, reg_lambda=0.75, subsample=0.9;, score=(train=1.000, test=0.408) total time=   3.1s
# [CV 4/5] END booster=gbtree, eta=0.1, max_depth=16, reg_lambda=0.75, subsample=0.9;, score=(train=1.000, test=0.563) total time=   3.6s
# [CV 5/5] END booster=gbtree, eta=0.1, max_depth=16, reg_lambda=0.75, subsample=0.9;, score=(train=1.000, test=0.535) total time=   3.6s
# [CV 1/5] END booster=gbtree, eta=0.1, max_depth=16, reg_lambda=0.75, subsample=1;, score=(train=1.000, test=0.326) total time=   4.2s
# [CV 2/5] END booster=gbtree, eta=0.1, max_depth=16, reg_lambda=0.75, subsample=1;, score=(train=1.000, test=0.408) total time=   4.0s
# [CV 3/5] END booster=gbtree, eta=0.1, max_depth=16, reg_lambda=0.75, subsample=1;, score=(train=1.000, test=0.403) total time=   4.4s
# [CV 4/5] END booster=gbtree, eta=0.1, max_depth=16, reg_lambda=0.75, subsample=1;, score=(train=1.000, test=0.518) total time=   4.4s
# [CV 5/5] END booster=gbtree, eta=0.1, max_depth=16, reg_lambda=0.75, subsample=1;, score=(train=1.000, test=0.485) total time=   4.3s
# [CV 1/5] END booster=gbtree, eta=0.1, max_depth=16, reg_lambda=1.0, subsample=0.8;, score=(train=1.000, test=0.216) total time=   2.6s
# [CV 2/5] END booster=gbtree, eta=0.1, max_depth=16, reg_lambda=1.0, subsample=0.8;, score=(train=1.000, test=0.437) total time=   2.8s
# [CV 3/5] END booster=gbtree, eta=0.1, max_depth=16, reg_lambda=1.0, subsample=0.8;, score=(train=1.000, test=0.457) total time=   2.7s
# [CV 4/5] END booster=gbtree, eta=0.1, max_depth=16, reg_lambda=1.0, subsample=0.8;, score=(train=1.000, test=0.524) total time=   3.5s
# [CV 5/5] END booster=gbtree, eta=0.1, max_depth=16, reg_lambda=1.0, subsample=0.8;, score=(train=1.000, test=0.471) total time=   2.8s
# [CV 1/5] END booster=gbtree, eta=0.1, max_depth=16, reg_lambda=1.0, subsample=0.9;, score=(train=1.000, test=0.264) total time=   3.0s
# [CV 2/5] END booster=gbtree, eta=0.1, max_depth=16, reg_lambda=1.0, subsample=0.9;, score=(train=1.000, test=0.395) total time=   3.0s
# [CV 3/5] END booster=gbtree, eta=0.1, max_depth=16, reg_lambda=1.0, subsample=0.9;, score=(train=1.000, test=0.404) total time=   3.4s
# [CV 4/5] END booster=gbtree, eta=0.1, max_depth=16, reg_lambda=1.0, subsample=0.9;, score=(train=1.000, test=0.541) total time=   3.2s
# [CV 5/5] END booster=gbtree, eta=0.1, max_depth=16, reg_lambda=1.0, subsample=0.9;, score=(train=1.000, test=0.501) total time=   3.5s
# [CV 1/5] END booster=gbtree, eta=0.1, max_depth=16, reg_lambda=1.0, subsample=1;, score=(train=1.000, test=0.284) total time=   3.9s
# [CV 2/5] END booster=gbtree, eta=0.1, max_depth=16, reg_lambda=1.0, subsample=1;, score=(train=1.000, test=0.357) total time=   3.3s
# [CV 3/5] END booster=gbtree, eta=0.1, max_depth=16, reg_lambda=1.0, subsample=1;, score=(train=1.000, test=0.430) total time=   4.1s
# [CV 4/5] END booster=gbtree, eta=0.1, max_depth=16, reg_lambda=1.0, subsample=1;, score=(train=1.000, test=0.515) total time=   3.7s
# [CV 5/5] END booster=gbtree, eta=0.1, max_depth=16, reg_lambda=1.0, subsample=1;, score=(train=1.000, test=0.414) total time=   4.2s
# [CV 1/5] END booster=gbtree, eta=0.05, max_depth=14, reg_lambda=0.5, subsample=0.8;, score=(train=0.999, test=0.239) total time=   2.8s
# [CV 2/5] END booster=gbtree, eta=0.05, max_depth=14, reg_lambda=0.5, subsample=0.8;, score=(train=0.999, test=0.439) total time=   3.7s
# [CV 3/5] END booster=gbtree, eta=0.05, max_depth=14, reg_lambda=0.5, subsample=0.8;, score=(train=0.999, test=0.420) total time=   3.4s
# [CV 4/5] END booster=gbtree, eta=0.05, max_depth=14, reg_lambda=0.5, subsample=0.8;, score=(train=0.999, test=0.549) total time=   3.1s
# [CV 5/5] END booster=gbtree, eta=0.05, max_depth=14, reg_lambda=0.5, subsample=0.8;, score=(train=0.999, test=0.519) total time=   3.4s
# [CV 1/5] END booster=gbtree, eta=0.05, max_depth=14, reg_lambda=0.5, subsample=0.9;, score=(train=1.000, test=0.286) total time=   3.2s
# [CV 2/5] END booster=gbtree, eta=0.05, max_depth=14, reg_lambda=0.5, subsample=0.9;, score=(train=1.000, test=0.410) total time=   3.3s
# [CV 3/5] END booster=gbtree, eta=0.05, max_depth=14, reg_lambda=0.5, subsample=0.9;, score=(train=1.000, test=0.420) total time=   3.7s
# [CV 4/5] END booster=gbtree, eta=0.05, max_depth=14, reg_lambda=0.5, subsample=0.9;, score=(train=1.000, test=0.517) total time=   4.1s
# [CV 5/5] END booster=gbtree, eta=0.05, max_depth=14, reg_lambda=0.5, subsample=0.9;, score=(train=1.000, test=0.473) total time=   3.6s
# [CV 1/5] END booster=gbtree, eta=0.05, max_depth=14, reg_lambda=0.5, subsample=1;, score=(train=1.000, test=0.323) total time=   3.6s
# [CV 2/5] END booster=gbtree, eta=0.05, max_depth=14, reg_lambda=0.5, subsample=1;, score=(train=1.000, test=0.373) total time=   3.7s
# [CV 3/5] END booster=gbtree, eta=0.05, max_depth=14, reg_lambda=0.5, subsample=1;, score=(train=1.000, test=0.419) total time=   3.4s
# [CV 4/5] END booster=gbtree, eta=0.05, max_depth=14, reg_lambda=0.5, subsample=1;, score=(train=1.000, test=0.506) total time=   3.8s
# [CV 5/5] END booster=gbtree, eta=0.05, max_depth=14, reg_lambda=0.5, subsample=1;, score=(train=1.000, test=0.480) total time=   3.8s
# [CV 1/5] END booster=gbtree, eta=0.05, max_depth=14, reg_lambda=0.75, subsample=0.8;, score=(train=0.999, test=0.182) total time=   2.5s
# [CV 2/5] END booster=gbtree, eta=0.05, max_depth=14, reg_lambda=0.75, subsample=0.8;, score=(train=0.999, test=0.434) total time=   2.0s
# [CV 3/5] END booster=gbtree, eta=0.05, max_depth=14, reg_lambda=0.75, subsample=0.8;, score=(train=0.998, test=0.451) total time=   1.9s
# [CV 4/5] END booster=gbtree, eta=0.05, max_depth=14, reg_lambda=0.75, subsample=0.8;, score=(train=0.999, test=0.523) total time=   2.5s
# [CV 5/5] END booster=gbtree, eta=0.05, max_depth=14, reg_lambda=0.75, subsample=0.8;, score=(train=0.998, test=0.482) total time=   1.9s
# [CV 1/5] END booster=gbtree, eta=0.05, max_depth=14, reg_lambda=0.75, subsample=0.9;, score=(train=0.999, test=0.308) total time=   2.4s
# [CV 2/5] END booster=gbtree, eta=0.05, max_depth=14, reg_lambda=0.75, subsample=0.9;, score=(train=0.999, test=0.401) total time=   2.0s
# [CV 3/5] END booster=gbtree, eta=0.05, max_depth=14, reg_lambda=0.75, subsample=0.9;, score=(train=0.999, test=0.419) total time=   2.3s
# [CV 4/5] END booster=gbtree, eta=0.05, max_depth=14, reg_lambda=0.75, subsample=0.9;, score=(train=0.999, test=0.536) total time=   2.3s
# [CV 5/5] END booster=gbtree, eta=0.05, max_depth=14, reg_lambda=0.75, subsample=0.9;, score=(train=0.999, test=0.473) total time=   2.4s
# [CV 1/5] END booster=gbtree, eta=0.05, max_depth=14, reg_lambda=0.75, subsample=1;, score=(train=1.000, test=0.353) total time=   2.4s
# [CV 2/5] END booster=gbtree, eta=0.05, max_depth=14, reg_lambda=0.75, subsample=1;, score=(train=1.000, test=0.396) total time=   2.4s
# [CV 3/5] END booster=gbtree, eta=0.05, max_depth=14, reg_lambda=0.75, subsample=1;, score=(train=1.000, test=0.417) total time=   2.6s
# [CV 4/5] END booster=gbtree, eta=0.05, max_depth=14, reg_lambda=0.75, subsample=1;, score=(train=1.000, test=0.504) total time=   2.6s
# [CV 5/5] END booster=gbtree, eta=0.05, max_depth=14, reg_lambda=0.75, subsample=1;, score=(train=1.000, test=0.466) total time=   2.7s
# [CV 1/5] END booster=gbtree, eta=0.05, max_depth=14, reg_lambda=1.0, subsample=0.8;, score=(train=0.998, test=0.208) total time=   1.8s
# [CV 2/5] END booster=gbtree, eta=0.05, max_depth=14, reg_lambda=1.0, subsample=0.8;, score=(train=0.998, test=0.417) total time=   2.0s
# [CV 3/5] END booster=gbtree, eta=0.05, max_depth=14, reg_lambda=1.0, subsample=0.8;, score=(train=0.998, test=0.398) total time=   1.8s
# [CV 4/5] END booster=gbtree, eta=0.05, max_depth=14, reg_lambda=1.0, subsample=0.8;, score=(train=0.998, test=0.558) total time=   1.9s
# [CV 5/5] END booster=gbtree, eta=0.05, max_depth=14, reg_lambda=1.0, subsample=0.8;, score=(train=0.998, test=0.452) total time=   2.1s
# [CV 1/5] END booster=gbtree, eta=0.05, max_depth=14, reg_lambda=1.0, subsample=0.9;, score=(train=0.999, test=0.297) total time=   2.0s
# [CV 2/5] END booster=gbtree, eta=0.05, max_depth=14, reg_lambda=1.0, subsample=0.9;, score=(train=0.999, test=0.394) total time=   2.2s
# [CV 3/5] END booster=gbtree, eta=0.05, max_depth=14, reg_lambda=1.0, subsample=0.9;, score=(train=0.999, test=0.420) total time=   2.1s
# [CV 4/5] END booster=gbtree, eta=0.05, max_depth=14, reg_lambda=1.0, subsample=0.9;, score=(train=0.999, test=0.500) total time=   2.4s
# [CV 5/5] END booster=gbtree, eta=0.05, max_depth=14, reg_lambda=1.0, subsample=0.9;, score=(train=0.999, test=0.456) total time=   2.2s
# [CV 1/5] END booster=gbtree, eta=0.05, max_depth=14, reg_lambda=1.0, subsample=1;, score=(train=0.999, test=0.292) total time=   2.2s
# [CV 2/5] END booster=gbtree, eta=0.05, max_depth=14, reg_lambda=1.0, subsample=1;, score=(train=0.999, test=0.385) total time=   2.5s
# [CV 3/5] END booster=gbtree, eta=0.05, max_depth=14, reg_lambda=1.0, subsample=1;, score=(train=0.999, test=0.406) total time=   2.1s
# [CV 4/5] END booster=gbtree, eta=0.05, max_depth=14, reg_lambda=1.0, subsample=1;, score=(train=0.999, test=0.504) total time=   2.5s
# [CV 5/5] END booster=gbtree, eta=0.05, max_depth=14, reg_lambda=1.0, subsample=1;, score=(train=0.999, test=0.451) total time=   2.3s
# [CV 1/5] END booster=gbtree, eta=0.05, max_depth=15, reg_lambda=0.5, subsample=0.8;, score=(train=0.999, test=0.232) total time=   2.3s
# [CV 2/5] END booster=gbtree, eta=0.05, max_depth=15, reg_lambda=0.5, subsample=0.8;, score=(train=0.999, test=0.432) total time=   2.0s
# [CV 3/5] END booster=gbtree, eta=0.05, max_depth=15, reg_lambda=0.5, subsample=0.8;, score=(train=0.999, test=0.418) total time=   2.3s
# [CV 4/5] END booster=gbtree, eta=0.05, max_depth=15, reg_lambda=0.5, subsample=0.8;, score=(train=0.999, test=0.540) total time=   2.2s
# [CV 5/5] END booster=gbtree, eta=0.05, max_depth=15, reg_lambda=0.5, subsample=0.8;, score=(train=0.999, test=0.537) total time=   2.6s
# [CV 1/5] END booster=gbtree, eta=0.05, max_depth=15, reg_lambda=0.5, subsample=0.9;, score=(train=1.000, test=0.288) total time=   2.5s
# [CV 2/5] END booster=gbtree, eta=0.05, max_depth=15, reg_lambda=0.5, subsample=0.9;, score=(train=1.000, test=0.413) total time=   2.6s
# [CV 3/5] END booster=gbtree, eta=0.05, max_depth=15, reg_lambda=0.5, subsample=0.9;, score=(train=1.000, test=0.421) total time=   2.4s
# [CV 4/5] END booster=gbtree, eta=0.05, max_depth=15, reg_lambda=0.5, subsample=0.9;, score=(train=1.000, test=0.519) total time=   2.7s
# [CV 5/5] END booster=gbtree, eta=0.05, max_depth=15, reg_lambda=0.5, subsample=0.9;, score=(train=1.000, test=0.487) total time=   2.5s
# [CV 1/5] END booster=gbtree, eta=0.05, max_depth=15, reg_lambda=0.5, subsample=1;, score=(train=1.000, test=0.323) total time=   2.8s
# [CV 2/5] END booster=gbtree, eta=0.05, max_depth=15, reg_lambda=0.5, subsample=1;, score=(train=1.000, test=0.370) total time=   2.7s
# [CV 3/5] END booster=gbtree, eta=0.05, max_depth=15, reg_lambda=0.5, subsample=1;, score=(train=1.000, test=0.419) total time=   2.8s
# [CV 4/5] END booster=gbtree, eta=0.05, max_depth=15, reg_lambda=0.5, subsample=1;, score=(train=1.000, test=0.513) total time=   2.7s
# [CV 5/5] END booster=gbtree, eta=0.05, max_depth=15, reg_lambda=0.5, subsample=1;, score=(train=1.000, test=0.468) total time=   3.0s
# [CV 1/5] END booster=gbtree, eta=0.05, max_depth=15, reg_lambda=0.75, subsample=0.8;, score=(train=0.999, test=0.198) total time=   2.0s
# [CV 2/5] END booster=gbtree, eta=0.05, max_depth=15, reg_lambda=0.75, subsample=0.8;, score=(train=0.999, test=0.427) total time=   2.2s
# [CV 3/5] END booster=gbtree, eta=0.05, max_depth=15, reg_lambda=0.75, subsample=0.8;, score=(train=0.998, test=0.440) total time=   2.0s
# [CV 4/5] END booster=gbtree, eta=0.05, max_depth=15, reg_lambda=0.75, subsample=0.8;, score=(train=0.998, test=0.539) total time=   2.4s
# [CV 5/5] END booster=gbtree, eta=0.05, max_depth=15, reg_lambda=0.75, subsample=0.8;, score=(train=0.998, test=0.482) total time=   2.1s
# [CV 1/5] END booster=gbtree, eta=0.05, max_depth=15, reg_lambda=0.75, subsample=0.9;, score=(train=0.999, test=0.305) total time=   2.6s
# [CV 2/5] END booster=gbtree, eta=0.05, max_depth=15, reg_lambda=0.75, subsample=0.9;, score=(train=0.999, test=0.400) total time=   2.3s
# [CV 3/5] END booster=gbtree, eta=0.05, max_depth=15, reg_lambda=0.75, subsample=0.9;, score=(train=0.999, test=0.421) total time=   2.5s
# [CV 4/5] END booster=gbtree, eta=0.05, max_depth=15, reg_lambda=0.75, subsample=0.9;, score=(train=0.999, test=0.540) total time=   2.4s
# [CV 5/5] END booster=gbtree, eta=0.05, max_depth=15, reg_lambda=0.75, subsample=0.9;, score=(train=0.999, test=0.466) total time=   2.7s
# [CV 1/5] END booster=gbtree, eta=0.05, max_depth=15, reg_lambda=0.75, subsample=1;, score=(train=1.000, test=0.354) total time=   2.7s
# [CV 2/5] END booster=gbtree, eta=0.05, max_depth=15, reg_lambda=0.75, subsample=1;, score=(train=1.000, test=0.396) total time=   2.8s
# [CV 3/5] END booster=gbtree, eta=0.05, max_depth=15, reg_lambda=0.75, subsample=1;, score=(train=1.000, test=0.417) total time=   2.4s
# [CV 4/5] END booster=gbtree, eta=0.05, max_depth=15, reg_lambda=0.75, subsample=1;, score=(train=1.000, test=0.495) total time=   2.8s
# [CV 5/5] END booster=gbtree, eta=0.05, max_depth=15, reg_lambda=0.75, subsample=1;, score=(train=1.000, test=0.473) total time=   2.5s
# [CV 1/5] END booster=gbtree, eta=0.05, max_depth=15, reg_lambda=1.0, subsample=0.8;, score=(train=0.998, test=0.217) total time=   2.2s
# [CV 2/5] END booster=gbtree, eta=0.05, max_depth=15, reg_lambda=1.0, subsample=0.8;, score=(train=0.998, test=0.415) total time=   1.8s
# [CV 3/5] END booster=gbtree, eta=0.05, max_depth=15, reg_lambda=1.0, subsample=0.8;, score=(train=0.998, test=0.397) total time=   2.1s
# [CV 4/5] END booster=gbtree, eta=0.05, max_depth=15, reg_lambda=1.0, subsample=0.8;, score=(train=0.998, test=0.547) total time=   3.3s
# [CV 5/5] END booster=gbtree, eta=0.05, max_depth=15, reg_lambda=1.0, subsample=0.8;, score=(train=0.998, test=0.436) total time=   2.1s
# [CV 1/5] END booster=gbtree, eta=0.05, max_depth=15, reg_lambda=1.0, subsample=0.9;, score=(train=0.999, test=0.292) total time=   2.4s
# [CV 2/5] END booster=gbtree, eta=0.05, max_depth=15, reg_lambda=1.0, subsample=0.9;, score=(train=0.999, test=0.393) total time=   2.1s
# [CV 3/5] END booster=gbtree, eta=0.05, max_depth=15, reg_lambda=1.0, subsample=0.9;, score=(train=0.999, test=0.419) total time=   2.2s
# [CV 4/5] END booster=gbtree, eta=0.05, max_depth=15, reg_lambda=1.0, subsample=0.9;, score=(train=0.999, test=0.498) total time=   2.5s
# [CV 5/5] END booster=gbtree, eta=0.05, max_depth=15, reg_lambda=1.0, subsample=0.9;, score=(train=0.999, test=0.455) total time=   2.3s
# [CV 1/5] END booster=gbtree, eta=0.05, max_depth=15, reg_lambda=1.0, subsample=1;, score=(train=0.999, test=0.296) total time=   2.7s
# [CV 2/5] END booster=gbtree, eta=0.05, max_depth=15, reg_lambda=1.0, subsample=1;, score=(train=0.999, test=0.386) total time=   2.4s
# [CV 3/5] END booster=gbtree, eta=0.05, max_depth=15, reg_lambda=1.0, subsample=1;, score=(train=0.999, test=0.408) total time=   2.5s
# [CV 4/5] END booster=gbtree, eta=0.05, max_depth=15, reg_lambda=1.0, subsample=1;, score=(train=0.999, test=0.501) total time=   2.4s
# [CV 5/5] END booster=gbtree, eta=0.05, max_depth=15, reg_lambda=1.0, subsample=1;, score=(train=0.999, test=0.449) total time=   2.6s
# [CV 1/5] END booster=gbtree, eta=0.05, max_depth=16, reg_lambda=0.5, subsample=0.8;, score=(train=0.999, test=0.229) total time=   2.3s
# [CV 2/5] END booster=gbtree, eta=0.05, max_depth=16, reg_lambda=0.5, subsample=0.8;, score=(train=0.999, test=0.434) total time=   2.5s
# [CV 3/5] END booster=gbtree, eta=0.05, max_depth=16, reg_lambda=0.5, subsample=0.8;, score=(train=0.999, test=0.420) total time=   2.4s
# [CV 4/5] END booster=gbtree, eta=0.05, max_depth=16, reg_lambda=0.5, subsample=0.8;, score=(train=0.999, test=0.539) total time=   2.6s
# [CV 5/5] END booster=gbtree, eta=0.05, max_depth=16, reg_lambda=0.5, subsample=0.8;, score=(train=0.999, test=0.534) total time=   3.4s
# [CV 1/5] END booster=gbtree, eta=0.05, max_depth=16, reg_lambda=0.5, subsample=0.9;, score=(train=1.000, test=0.290) total time=   3.2s
# [CV 2/5] END booster=gbtree, eta=0.05, max_depth=16, reg_lambda=0.5, subsample=0.9;, score=(train=1.000, test=0.409) total time=   3.1s
# [CV 3/5] END booster=gbtree, eta=0.05, max_depth=16, reg_lambda=0.5, subsample=0.9;, score=(train=1.000, test=0.421) total time=   2.6s
# [CV 4/5] END booster=gbtree, eta=0.05, max_depth=16, reg_lambda=0.5, subsample=0.9;, score=(train=1.000, test=0.520) total time=   2.9s
# [CV 5/5] END booster=gbtree, eta=0.05, max_depth=16, reg_lambda=0.5, subsample=0.9;, score=(train=1.000, test=0.487) total time=   2.7s
# [CV 1/5] END booster=gbtree, eta=0.05, max_depth=16, reg_lambda=0.5, subsample=1;, score=(train=1.000, test=0.323) total time=   3.9s
# [CV 2/5] END booster=gbtree, eta=0.05, max_depth=16, reg_lambda=0.5, subsample=1;, score=(train=1.000, test=0.373) total time=   3.3s
# [CV 3/5] END booster=gbtree, eta=0.05, max_depth=16, reg_lambda=0.5, subsample=1;, score=(train=1.000, test=0.419) total time=   2.8s
# [CV 4/5] END booster=gbtree, eta=0.05, max_depth=16, reg_lambda=0.5, subsample=1;, score=(train=1.000, test=0.519) total time=   3.3s
# [CV 5/5] END booster=gbtree, eta=0.05, max_depth=16, reg_lambda=0.5, subsample=1;, score=(train=1.000, test=0.463) total time=   3.1s
# [CV 1/5] END booster=gbtree, eta=0.05, max_depth=16, reg_lambda=0.75, subsample=0.8;, score=(train=0.999, test=0.209) total time=   2.4s
# [CV 2/5] END booster=gbtree, eta=0.05, max_depth=16, reg_lambda=0.75, subsample=0.8;, score=(train=0.998, test=0.427) total time=   2.3s
# [CV 3/5] END booster=gbtree, eta=0.05, max_depth=16, reg_lambda=0.75, subsample=0.8;, score=(train=0.998, test=0.441) total time=   2.5s
# [CV 4/5] END booster=gbtree, eta=0.05, max_depth=16, reg_lambda=0.75, subsample=0.8;, score=(train=0.999, test=0.542) total time=   2.2s
# [CV 5/5] END booster=gbtree, eta=0.05, max_depth=16, reg_lambda=0.75, subsample=0.8;, score=(train=0.998, test=0.468) total time=   2.4s
# [CV 1/5] END booster=gbtree, eta=0.05, max_depth=16, reg_lambda=0.75, subsample=0.9;, score=(train=0.999, test=0.303) total time=   3.3s
# [CV 2/5] END booster=gbtree, eta=0.05, max_depth=16, reg_lambda=0.75, subsample=0.9;, score=(train=0.999, test=0.400) total time=   2.7s
# [CV 3/5] END booster=gbtree, eta=0.05, max_depth=16, reg_lambda=0.75, subsample=0.9;, score=(train=0.999, test=0.420) total time=   2.5s
# [CV 4/5] END booster=gbtree, eta=0.05, max_depth=16, reg_lambda=0.75, subsample=0.9;, score=(train=0.999, test=0.537) total time=   2.8s
# [CV 5/5] END booster=gbtree, eta=0.05, max_depth=16, reg_lambda=0.75, subsample=0.9;, score=(train=0.999, test=0.468) total time=   2.7s
# [CV 1/5] END booster=gbtree, eta=0.05, max_depth=16, reg_lambda=0.75, subsample=1;, score=(train=1.000, test=0.353) total time=   4.3s
# [CV 2/5] END booster=gbtree, eta=0.05, max_depth=16, reg_lambda=0.75, subsample=1;, score=(train=1.000, test=0.396) total time=   3.0s
# [CV 3/5] END booster=gbtree, eta=0.05, max_depth=16, reg_lambda=0.75, subsample=1;, score=(train=1.000, test=0.417) total time=   2.9s
# [CV 4/5] END booster=gbtree, eta=0.05, max_depth=16, reg_lambda=0.75, subsample=1;, score=(train=1.000, test=0.506) total time=   2.7s
# [CV 5/5] END booster=gbtree, eta=0.05, max_depth=16, reg_lambda=0.75, subsample=1;, score=(train=1.000, test=0.471) total time=   3.8s
# [CV 1/5] END booster=gbtree, eta=0.05, max_depth=16, reg_lambda=1.0, subsample=0.8;, score=(train=0.998, test=0.209) total time=   3.0s
# [CV 2/5] END booster=gbtree, eta=0.05, max_depth=16, reg_lambda=1.0, subsample=0.8;, score=(train=0.998, test=0.414) total time=   2.1s
# [CV 3/5] END booster=gbtree, eta=0.05, max_depth=16, reg_lambda=1.0, subsample=0.8;, score=(train=0.998, test=0.398) total time=   2.6s
# [CV 4/5] END booster=gbtree, eta=0.05, max_depth=16, reg_lambda=1.0, subsample=0.8;, score=(train=0.998, test=0.547) total time=   2.2s
# [CV 5/5] END booster=gbtree, eta=0.05, max_depth=16, reg_lambda=1.0, subsample=0.8;, score=(train=0.998, test=0.443) total time=   2.0s
# [CV 1/5] END booster=gbtree, eta=0.05, max_depth=16, reg_lambda=1.0, subsample=0.9;, score=(train=0.999, test=0.294) total time=   2.8s
# [CV 2/5] END booster=gbtree, eta=0.05, max_depth=16, reg_lambda=1.0, subsample=0.9;, score=(train=0.999, test=0.391) total time=   2.3s
# [CV 3/5] END booster=gbtree, eta=0.05, max_depth=16, reg_lambda=1.0, subsample=0.9;, score=(train=0.999, test=0.419) total time=   2.7s
# [CV 4/5] END booster=gbtree, eta=0.05, max_depth=16, reg_lambda=1.0, subsample=0.9;, score=(train=0.999, test=0.492) total time=   2.3s
# [CV 5/5] END booster=gbtree, eta=0.05, max_depth=16, reg_lambda=1.0, subsample=0.9;, score=(train=0.999, test=0.448) total time=   2.7s
# [CV 1/5] END booster=gbtree, eta=0.05, max_depth=16, reg_lambda=1.0, subsample=1;, score=(train=0.999, test=0.296) total time=   2.6s
# [CV 2/5] END booster=gbtree, eta=0.05, max_depth=16, reg_lambda=1.0, subsample=1;, score=(train=0.999, test=0.385) total time=   2.8s
# [CV 3/5] END booster=gbtree, eta=0.05, max_depth=16, reg_lambda=1.0, subsample=1;, score=(train=0.999, test=0.408) total time=   2.5s
# [CV 4/5] END booster=gbtree, eta=0.05, max_depth=16, reg_lambda=1.0, subsample=1;, score=(train=0.999, test=0.502) total time=   2.6s
# [CV 5/5] END booster=gbtree, eta=0.05, max_depth=16, reg_lambda=1.0, subsample=1;, score=(train=0.999, test=0.433) total time=   2.6s
# [CV 1/5] END booster=gbtree, eta=0.01, max_depth=14, reg_lambda=0.5, subsample=0.8;, score=(train=0.786, test=-0.044) total time=   1.9s
# [CV 2/5] END booster=gbtree, eta=0.01, max_depth=14, reg_lambda=0.5, subsample=0.8;, score=(train=0.770, test=0.125) total time=   1.6s
# [CV 3/5] END booster=gbtree, eta=0.01, max_depth=14, reg_lambda=0.5, subsample=0.8;, score=(train=0.757, test=0.260) total time=   2.0s
# [CV 4/5] END booster=gbtree, eta=0.01, max_depth=14, reg_lambda=0.5, subsample=0.8;, score=(train=0.746, test=0.481) total time=   1.5s
# [CV 5/5] END booster=gbtree, eta=0.01, max_depth=14, reg_lambda=0.5, subsample=0.8;, score=(train=0.746, test=0.375) total time=   1.9s
# [CV 1/5] END booster=gbtree, eta=0.01, max_depth=14, reg_lambda=0.5, subsample=0.9;, score=(train=0.801, test=0.001) total time=   1.9s
# [CV 2/5] END booster=gbtree, eta=0.01, max_depth=14, reg_lambda=0.5, subsample=0.9;, score=(train=0.792, test=0.114) total time=   1.9s
# [CV 3/5] END booster=gbtree, eta=0.01, max_depth=14, reg_lambda=0.5, subsample=0.9;, score=(train=0.778, test=0.260) total time=   2.2s
# [CV 4/5] END booster=gbtree, eta=0.01, max_depth=14, reg_lambda=0.5, subsample=0.9;, score=(train=0.769, test=0.477) total time=   1.8s
# [CV 5/5] END booster=gbtree, eta=0.01, max_depth=14, reg_lambda=0.5, subsample=0.9;, score=(train=0.768, test=0.357) total time=   1.8s
# [CV 1/5] END booster=gbtree, eta=0.01, max_depth=14, reg_lambda=0.5, subsample=1;, score=(train=0.815, test=0.055) total time=   2.4s
# [CV 2/5] END booster=gbtree, eta=0.01, max_depth=14, reg_lambda=0.5, subsample=1;, score=(train=0.808, test=0.052) total time=   2.9s
# [CV 3/5] END booster=gbtree, eta=0.01, max_depth=14, reg_lambda=0.5, subsample=1;, score=(train=0.792, test=0.260) total time=   2.2s
# [CV 4/5] END booster=gbtree, eta=0.01, max_depth=14, reg_lambda=0.5, subsample=1;, score=(train=0.787, test=0.455) total time=   2.0s
# [CV 5/5] END booster=gbtree, eta=0.01, max_depth=14, reg_lambda=0.5, subsample=1;, score=(train=0.786, test=0.300) total time=   2.3s
# [CV 1/5] END booster=gbtree, eta=0.01, max_depth=14, reg_lambda=0.75, subsample=0.8;, score=(train=0.777, test=-0.054) total time=   1.5s
# [CV 2/5] END booster=gbtree, eta=0.01, max_depth=14, reg_lambda=0.75, subsample=0.8;, score=(train=0.762, test=0.123) total time=   1.7s
# [CV 3/5] END booster=gbtree, eta=0.01, max_depth=14, reg_lambda=0.75, subsample=0.8;, score=(train=0.746, test=0.249) total time=   1.7s
# [CV 4/5] END booster=gbtree, eta=0.01, max_depth=14, reg_lambda=0.75, subsample=0.8;, score=(train=0.736, test=0.475) total time=   1.5s
# [CV 5/5] END booster=gbtree, eta=0.01, max_depth=14, reg_lambda=0.75, subsample=0.8;, score=(train=0.735, test=0.348) total time=   1.6s
# [CV 1/5] END booster=gbtree, eta=0.01, max_depth=14, reg_lambda=0.75, subsample=0.9;, score=(train=0.793, test=0.008) total time=   1.9s
# [CV 2/5] END booster=gbtree, eta=0.01, max_depth=14, reg_lambda=0.75, subsample=0.9;, score=(train=0.783, test=0.100) total time=   1.8s
# [CV 3/5] END booster=gbtree, eta=0.01, max_depth=14, reg_lambda=0.75, subsample=0.9;, score=(train=0.768, test=0.258) total time=   1.7s
# [CV 4/5] END booster=gbtree, eta=0.01, max_depth=14, reg_lambda=0.75, subsample=0.9;, score=(train=0.759, test=0.456) total time=   1.9s
# [CV 5/5] END booster=gbtree, eta=0.01, max_depth=14, reg_lambda=0.75, subsample=0.9;, score=(train=0.759, test=0.319) total time=   1.6s
# [CV 1/5] END booster=gbtree, eta=0.01, max_depth=14, reg_lambda=0.75, subsample=1;, score=(train=0.807, test=0.118) total time=   2.1s
# [CV 2/5] END booster=gbtree, eta=0.01, max_depth=14, reg_lambda=0.75, subsample=1;, score=(train=0.800, test=0.062) total time=   1.8s
# [CV 3/5] END booster=gbtree, eta=0.01, max_depth=14, reg_lambda=0.75, subsample=1;, score=(train=0.783, test=0.257) total time=   1.8s
# [CV 4/5] END booster=gbtree, eta=0.01, max_depth=14, reg_lambda=0.75, subsample=1;, score=(train=0.777, test=0.460) total time=   2.1s
# [CV 5/5] END booster=gbtree, eta=0.01, max_depth=14, reg_lambda=0.75, subsample=1;, score=(train=0.777, test=0.285) total time=   1.7s
# [CV 1/5] END booster=gbtree, eta=0.01, max_depth=14, reg_lambda=1.0, subsample=0.8;, score=(train=0.768, test=-0.061) total time=   1.6s
# [CV 2/5] END booster=gbtree, eta=0.01, max_depth=14, reg_lambda=1.0, subsample=0.8;, score=(train=0.753, test=0.110) total time=   1.6s
# [CV 3/5] END booster=gbtree, eta=0.01, max_depth=14, reg_lambda=1.0, subsample=0.8;, score=(train=0.738, test=0.261) total time=   1.5s
# [CV 4/5] END booster=gbtree, eta=0.01, max_depth=14, reg_lambda=1.0, subsample=0.8;, score=(train=0.726, test=0.467) total time=   1.3s
# [CV 5/5] END booster=gbtree, eta=0.01, max_depth=14, reg_lambda=1.0, subsample=0.8;, score=(train=0.726, test=0.328) total time=   1.8s
# [CV 1/5] END booster=gbtree, eta=0.01, max_depth=14, reg_lambda=1.0, subsample=0.9;, score=(train=0.786, test=-0.000) total time=   1.6s
# [CV 2/5] END booster=gbtree, eta=0.01, max_depth=14, reg_lambda=1.0, subsample=0.9;, score=(train=0.775, test=0.106) total time=   1.7s
# [CV 3/5] END booster=gbtree, eta=0.01, max_depth=14, reg_lambda=1.0, subsample=0.9;, score=(train=0.760, test=0.256) total time=   1.6s
# [CV 4/5] END booster=gbtree, eta=0.01, max_depth=14, reg_lambda=1.0, subsample=0.9;, score=(train=0.750, test=0.451) total time=   1.7s
# [CV 5/5] END booster=gbtree, eta=0.01, max_depth=14, reg_lambda=1.0, subsample=0.9;, score=(train=0.750, test=0.313) total time=   1.4s
# [CV 1/5] END booster=gbtree, eta=0.01, max_depth=14, reg_lambda=1.0, subsample=1;, score=(train=0.800, test=0.082) total time=   2.1s
# [CV 2/5] END booster=gbtree, eta=0.01, max_depth=14, reg_lambda=1.0, subsample=1;, score=(train=0.793, test=0.060) total time=   1.5s
# [CV 3/5] END booster=gbtree, eta=0.01, max_depth=14, reg_lambda=1.0, subsample=1;, score=(train=0.775, test=0.268) total time=   1.7s
# [CV 4/5] END booster=gbtree, eta=0.01, max_depth=14, reg_lambda=1.0, subsample=1;, score=(train=0.769, test=0.398) total time=   1.8s
# [CV 5/5] END booster=gbtree, eta=0.01, max_depth=14, reg_lambda=1.0, subsample=1;, score=(train=0.769, test=0.275) total time=   1.6s
# [CV 1/5] END booster=gbtree, eta=0.01, max_depth=15, reg_lambda=0.5, subsample=0.8;, score=(train=0.786, test=-0.044) total time=   1.9s
# [CV 2/5] END booster=gbtree, eta=0.01, max_depth=15, reg_lambda=0.5, subsample=0.8;, score=(train=0.770, test=0.125) total time=   2.0s
# [CV 3/5] END booster=gbtree, eta=0.01, max_depth=15, reg_lambda=0.5, subsample=0.8;, score=(train=0.757, test=0.260) total time=   1.7s
# [CV 4/5] END booster=gbtree, eta=0.01, max_depth=15, reg_lambda=0.5, subsample=0.8;, score=(train=0.746, test=0.481) total time=   1.8s
# [CV 5/5] END booster=gbtree, eta=0.01, max_depth=15, reg_lambda=0.5, subsample=0.8;, score=(train=0.746, test=0.374) total time=   2.0s
# [CV 1/5] END booster=gbtree, eta=0.01, max_depth=15, reg_lambda=0.5, subsample=0.9;, score=(train=0.801, test=0.001) total time=   2.1s
# [CV 2/5] END booster=gbtree, eta=0.01, max_depth=15, reg_lambda=0.5, subsample=0.9;, score=(train=0.792, test=0.114) total time=   2.2s
# [CV 3/5] END booster=gbtree, eta=0.01, max_depth=15, reg_lambda=0.5, subsample=0.9;, score=(train=0.778, test=0.260) total time=   1.8s
# [CV 4/5] END booster=gbtree, eta=0.01, max_depth=15, reg_lambda=0.5, subsample=0.9;, score=(train=0.769, test=0.478) total time=   1.9s
# [CV 5/5] END booster=gbtree, eta=0.01, max_depth=15, reg_lambda=0.5, subsample=0.9;, score=(train=0.768, test=0.356) total time=   2.1s
# [CV 1/5] END booster=gbtree, eta=0.01, max_depth=15, reg_lambda=0.5, subsample=1;, score=(train=0.815, test=0.055) total time=   2.2s
# [CV 2/5] END booster=gbtree, eta=0.01, max_depth=15, reg_lambda=0.5, subsample=1;, score=(train=0.808, test=0.052) total time=   2.4s
# [CV 3/5] END booster=gbtree, eta=0.01, max_depth=15, reg_lambda=0.5, subsample=1;, score=(train=0.792, test=0.260) total time=   2.0s
# [CV 4/5] END booster=gbtree, eta=0.01, max_depth=15, reg_lambda=0.5, subsample=1;, score=(train=0.787, test=0.451) total time=   2.2s
# [CV 5/5] END booster=gbtree, eta=0.01, max_depth=15, reg_lambda=0.5, subsample=1;, score=(train=0.786, test=0.287) total time=   1.9s
# [CV 1/5] END booster=gbtree, eta=0.01, max_depth=15, reg_lambda=0.75, subsample=0.8;, score=(train=0.777, test=-0.054) total time=   1.9s
# [CV 2/5] END booster=gbtree, eta=0.01, max_depth=15, reg_lambda=0.75, subsample=0.8;, score=(train=0.762, test=0.123) total time=   1.9s
# [CV 3/5] END booster=gbtree, eta=0.01, max_depth=15, reg_lambda=0.75, subsample=0.8;, score=(train=0.746, test=0.249) total time=   1.7s
# [CV 4/5] END booster=gbtree, eta=0.01, max_depth=15, reg_lambda=0.75, subsample=0.8;, score=(train=0.736, test=0.473) total time=   1.5s
# [CV 5/5] END booster=gbtree, eta=0.01, max_depth=15, reg_lambda=0.75, subsample=0.8;, score=(train=0.735, test=0.348) total time=   2.0s
# [CV 1/5] END booster=gbtree, eta=0.01, max_depth=15, reg_lambda=0.75, subsample=0.9;, score=(train=0.793, test=0.008) total time=   1.7s
# [CV 2/5] END booster=gbtree, eta=0.01, max_depth=15, reg_lambda=0.75, subsample=0.9;, score=(train=0.783, test=0.100) total time=   2.1s
# [CV 3/5] END booster=gbtree, eta=0.01, max_depth=15, reg_lambda=0.75, subsample=0.9;, score=(train=0.768, test=0.258) total time=   1.5s
# [CV 4/5] END booster=gbtree, eta=0.01, max_depth=15, reg_lambda=0.75, subsample=0.9;, score=(train=0.759, test=0.456) total time=   1.9s
# [CV 5/5] END booster=gbtree, eta=0.01, max_depth=15, reg_lambda=0.75, subsample=0.9;, score=(train=0.759, test=0.319) total time=   1.8s
# [CV 1/5] END booster=gbtree, eta=0.01, max_depth=15, reg_lambda=0.75, subsample=1;, score=(train=0.807, test=0.118) total time=   2.1s
# [CV 2/5] END booster=gbtree, eta=0.01, max_depth=15, reg_lambda=0.75, subsample=1;, score=(train=0.800, test=0.062) total time=   2.3s
# [CV 3/5] END booster=gbtree, eta=0.01, max_depth=15, reg_lambda=0.75, subsample=1;, score=(train=0.783, test=0.257) total time=   1.8s
# [CV 4/5] END booster=gbtree, eta=0.01, max_depth=15, reg_lambda=0.75, subsample=1;, score=(train=0.777, test=0.459) total time=   1.9s
# [CV 5/5] END booster=gbtree, eta=0.01, max_depth=15, reg_lambda=0.75, subsample=1;, score=(train=0.777, test=0.291) total time=   2.2s
# [CV 1/5] END booster=gbtree, eta=0.01, max_depth=15, reg_lambda=1.0, subsample=0.8;, score=(train=0.768, test=-0.061) total time=   1.5s
# [CV 2/5] END booster=gbtree, eta=0.01, max_depth=15, reg_lambda=1.0, subsample=0.8;, score=(train=0.753, test=0.110) total time=   1.7s
# [CV 3/5] END booster=gbtree, eta=0.01, max_depth=15, reg_lambda=1.0, subsample=0.8;, score=(train=0.738, test=0.261) total time=   1.6s
# [CV 4/5] END booster=gbtree, eta=0.01, max_depth=15, reg_lambda=1.0, subsample=0.8;, score=(train=0.726, test=0.467) total time=   1.6s
# [CV 5/5] END booster=gbtree, eta=0.01, max_depth=15, reg_lambda=1.0, subsample=0.8;, score=(train=0.726, test=0.328) total time=   1.5s
# [CV 1/5] END booster=gbtree, eta=0.01, max_depth=15, reg_lambda=1.0, subsample=0.9;, score=(train=0.786, test=-0.000) total time=   2.3s
# [CV 2/5] END booster=gbtree, eta=0.01, max_depth=15, reg_lambda=1.0, subsample=0.9;, score=(train=0.775, test=0.106) total time=   1.7s
# [CV 3/5] END booster=gbtree, eta=0.01, max_depth=15, reg_lambda=1.0, subsample=0.9;, score=(train=0.760, test=0.256) total time=   1.5s
# [CV 4/5] END booster=gbtree, eta=0.01, max_depth=15, reg_lambda=1.0, subsample=0.9;, score=(train=0.750, test=0.451) total time=   1.8s
# ...
# [CV 2/5] END booster=dart, eta=0.01, max_depth=14, reg_lambda=0.75, subsample=1;, score=(train=0.800, test=0.062) total time=   7.2s
# [CV 3/5] END booster=dart, eta=0.01, max_depth=14, reg_lambda=0.75, subsample=1;, score=(train=0.783, test=0.257) total time=   6.3s
# [CV 4/5] END booster=dart, eta=0.01, max_depth=14, reg_lambda=0.75, subsample=1;, score=(train=0.777, test=0.460) total time=   6.6s
# [CV 5/5] END booster=dart, eta=0.01, max_depth=14, reg_lambda=0.75, subsample=1;, score=(train=0.777, test=0.285) total time=   7.9s
# [CV 1/5] END booster=dart, eta=0.01, max_depth=14, reg_lambda=1.0, subsample=0.8;, score=(train=0.770, test=-0.029) total time=   7.4s
# [CV 2/5] END booster=dart, eta=0.01, max_depth=14, reg_lambda=1.0, subsample=0.8;, score=(train=0.754, test=0.118) total time=   7.5s
# [CV 3/5] END booster=dart, eta=0.01, max_depth=14, reg_lambda=1.0, subsample=0.8;, score=(train=0.740, test=0.258) total time=   7.4s
# [CV 4/5] END booster=dart, eta=0.01, max_depth=14, reg_lambda=1.0, subsample=0.8;, score=(train=0.729, test=0.467) total time=   7.6s
# [CV 5/5] END booster=dart, eta=0.01, max_depth=14, reg_lambda=1.0, subsample=0.8;, score=(train=0.729, test=0.325) total time=   7.5s
# [CV 1/5] END booster=dart, eta=0.01, max_depth=14, reg_lambda=1.0, subsample=0.9;, score=(train=0.786, test=0.006) total time=   7.6s
# [CV 2/5] END booster=dart, eta=0.01, max_depth=14, reg_lambda=1.0, subsample=0.9;, score=(train=0.773, test=0.097) total time=   6.2s
# [CV 3/5] END booster=dart, eta=0.01, max_depth=14, reg_lambda=1.0, subsample=0.9;, score=(train=0.759, test=0.262) total time=   6.4s
# [CV 4/5] END booster=dart, eta=0.01, max_depth=14, reg_lambda=1.0, subsample=0.9;, score=(train=0.750, test=0.465) total time=   5.9s
# [CV 5/5] END booster=dart, eta=0.01, max_depth=14, reg_lambda=1.0, subsample=0.9;, score=(train=0.751, test=0.296) total time=   7.8s
# [CV 1/5] END booster=dart, eta=0.01, max_depth=14, reg_lambda=1.0, subsample=1;, score=(train=0.800, test=0.082) total time=   8.1s
# [CV 2/5] END booster=dart, eta=0.01, max_depth=14, reg_lambda=1.0, subsample=1;, score=(train=0.793, test=0.060) total time=   7.9s
# [CV 3/5] END booster=dart, eta=0.01, max_depth=14, reg_lambda=1.0, subsample=1;, score=(train=0.775, test=0.268) total time=   7.1s
# [CV 4/5] END booster=dart, eta=0.01, max_depth=14, reg_lambda=1.0, subsample=1;, score=(train=0.769, test=0.398) total time=   6.6s
# [CV 5/5] END booster=dart, eta=0.01, max_depth=14, reg_lambda=1.0, subsample=1;, score=(train=0.769, test=0.275) total time=   6.4s
# [CV 1/5] END booster=dart, eta=0.01, max_depth=15, reg_lambda=0.5, subsample=0.8;, score=(train=0.785, test=-0.031) total time=   6.6s
# [CV 2/5] END booster=dart, eta=0.01, max_depth=15, reg_lambda=0.5, subsample=0.8;, score=(train=0.773, test=0.123) total time=   6.7s
# [CV 3/5] END booster=dart, eta=0.01, max_depth=15, reg_lambda=0.5, subsample=0.8;, score=(train=0.758, test=0.268) total time=   6.4s
# [CV 4/5] END booster=dart, eta=0.01, max_depth=15, reg_lambda=0.5, subsample=0.8;, score=(train=0.748, test=0.472) total time=   7.8s
# [CV 5/5] END booster=dart, eta=0.01, max_depth=15, reg_lambda=0.5, subsample=0.8;, score=(train=0.748, test=0.356) total time=   8.0s
# [CV 1/5] END booster=dart, eta=0.01, max_depth=15, reg_lambda=0.5, subsample=0.9;, score=(train=0.802, test=0.043) total time=   8.8s
# [CV 2/5] END booster=dart, eta=0.01, max_depth=15, reg_lambda=0.5, subsample=0.9;, score=(train=0.791, test=0.115) total time=   8.5s
# [CV 3/5] END booster=dart, eta=0.01, max_depth=15, reg_lambda=0.5, subsample=0.9;, score=(train=0.777, test=0.257) total time=   8.4s
# [CV 4/5] END booster=dart, eta=0.01, max_depth=15, reg_lambda=0.5, subsample=0.9;, score=(train=0.769, test=0.443) total time=   6.2s
# [CV 5/5] END booster=dart, eta=0.01, max_depth=15, reg_lambda=0.5, subsample=0.9;, score=(train=0.769, test=0.322) total time=   6.2s
# [CV 1/5] END booster=dart, eta=0.01, max_depth=15, reg_lambda=0.5, subsample=1;, score=(train=0.815, test=0.055) total time=   6.6s
# [CV 2/5] END booster=dart, eta=0.01, max_depth=15, reg_lambda=0.5, subsample=1;, score=(train=0.808, test=0.052) total time=   6.6s
# [CV 3/5] END booster=dart, eta=0.01, max_depth=15, reg_lambda=0.5, subsample=1;, score=(train=0.792, test=0.260) total time=   6.4s
# [CV 4/5] END booster=dart, eta=0.01, max_depth=15, reg_lambda=0.5, subsample=1;, score=(train=0.787, test=0.451) total time=   6.3s
# [CV 5/5] END booster=dart, eta=0.01, max_depth=15, reg_lambda=0.5, subsample=1;, score=(train=0.786, test=0.287) total time=   6.5s
# [CV 1/5] END booster=dart, eta=0.01, max_depth=15, reg_lambda=0.75, subsample=0.8;, score=(train=0.777, test=-0.014) total time=   6.2s
# [CV 2/5] END booster=dart, eta=0.01, max_depth=15, reg_lambda=0.75, subsample=0.8;, score=(train=0.763, test=0.122) total time=   6.1s
# [CV 3/5] END booster=dart, eta=0.01, max_depth=15, reg_lambda=0.75, subsample=0.8;, score=(train=0.748, test=0.259) total time=   5.9s
# [CV 4/5] END booster=dart, eta=0.01, max_depth=15, reg_lambda=0.75, subsample=0.8;, score=(train=0.738, test=0.465) total time=   6.0s
# [CV 5/5] END booster=dart, eta=0.01, max_depth=15, reg_lambda=0.75, subsample=0.8;, score=(train=0.738, test=0.335) total time=   5.8s
# [CV 1/5] END booster=dart, eta=0.01, max_depth=15, reg_lambda=0.75, subsample=0.9;, score=(train=0.793, test=0.031) total time=   6.4s
# [CV 2/5] END booster=dart, eta=0.01, max_depth=15, reg_lambda=0.75, subsample=0.9;, score=(train=0.782, test=0.106) total time=   6.2s
# [CV 3/5] END booster=dart, eta=0.01, max_depth=15, reg_lambda=0.75, subsample=0.9;, score=(train=0.767, test=0.257) total time=   6.2s
# [CV 4/5] END booster=dart, eta=0.01, max_depth=15, reg_lambda=0.75, subsample=0.9;, score=(train=0.758, test=0.453) total time=   5.9s
# [CV 5/5] END booster=dart, eta=0.01, max_depth=15, reg_lambda=0.75, subsample=0.9;, score=(train=0.758, test=0.314) total time=   6.1s
# [CV 1/5] END booster=dart, eta=0.01, max_depth=15, reg_lambda=0.75, subsample=1;, score=(train=0.807, test=0.118) total time=   6.5s
# [CV 2/5] END booster=dart, eta=0.01, max_depth=15, reg_lambda=0.75, subsample=1;, score=(train=0.800, test=0.062) total time=   6.4s
# [CV 3/5] END booster=dart, eta=0.01, max_depth=15, reg_lambda=0.75, subsample=1;, score=(train=0.783, test=0.257) total time=   6.1s
# [CV 4/5] END booster=dart, eta=0.01, max_depth=15, reg_lambda=0.75, subsample=1;, score=(train=0.777, test=0.459) total time=   6.3s
# [CV 5/5] END booster=dart, eta=0.01, max_depth=15, reg_lambda=0.75, subsample=1;, score=(train=0.777, test=0.291) total time=   6.2s
# [CV 1/5] END booster=dart, eta=0.01, max_depth=15, reg_lambda=1.0, subsample=0.8;, score=(train=0.770, test=-0.029) total time=   6.0s
# [CV 2/5] END booster=dart, eta=0.01, max_depth=15, reg_lambda=1.0, subsample=0.8;, score=(train=0.754, test=0.118) total time=   5.7s
# [CV 3/5] END booster=dart, eta=0.01, max_depth=15, reg_lambda=1.0, subsample=0.8;, score=(train=0.740, test=0.258) total time=   6.0s
# [CV 4/5] END booster=dart, eta=0.01, max_depth=15, reg_lambda=1.0, subsample=0.8;, score=(train=0.729, test=0.467) total time=   6.2s
# [CV 5/5] END booster=dart, eta=0.01, max_depth=15, reg_lambda=1.0, subsample=0.8;, score=(train=0.729, test=0.324) total time=   6.0s
# [CV 1/5] END booster=dart, eta=0.01, max_depth=15, reg_lambda=1.0, subsample=0.9;, score=(train=0.786, test=0.006) total time=   6.0s
# [CV 2/5] END booster=dart, eta=0.01, max_depth=15, reg_lambda=1.0, subsample=0.9;, score=(train=0.773, test=0.097) total time=   6.0s
# [CV 3/5] END booster=dart, eta=0.01, max_depth=15, reg_lambda=1.0, subsample=0.9;, score=(train=0.759, test=0.262) total time=   5.8s
# [CV 4/5] END booster=dart, eta=0.01, max_depth=15, reg_lambda=1.0, subsample=0.9;, score=(train=0.750, test=0.465) total time=  11.0s
# [CV 5/5] END booster=dart, eta=0.01, max_depth=15, reg_lambda=1.0, subsample=0.9;, score=(train=0.751, test=0.296) total time=   9.8s
# [CV 1/5] END booster=dart, eta=0.01, max_depth=15, reg_lambda=1.0, subsample=1;, score=(train=0.800, test=0.082) total time=   7.7s
# [CV 2/5] END booster=dart, eta=0.01, max_depth=15, reg_lambda=1.0, subsample=1;, score=(train=0.793, test=0.060) total time=   7.7s
# [CV 3/5] END booster=dart, eta=0.01, max_depth=15, reg_lambda=1.0, subsample=1;, score=(train=0.775, test=0.268) total time=   7.3s
# [CV 4/5] END booster=dart, eta=0.01, max_depth=15, reg_lambda=1.0, subsample=1;, score=(train=0.769, test=0.398) total time=   7.9s
# [CV 5/5] END booster=dart, eta=0.01, max_depth=15, reg_lambda=1.0, subsample=1;, score=(train=0.769, test=0.275) total time=   7.2s
# [CV 1/5] END booster=dart, eta=0.01, max_depth=16, reg_lambda=0.5, subsample=0.8;, score=(train=0.785, test=-0.031) total time=   7.1s
# [CV 2/5] END booster=dart, eta=0.01, max_depth=16, reg_lambda=0.5, subsample=0.8;, score=(train=0.773, test=0.123) total time=   6.4s
# [CV 3/5] END booster=dart, eta=0.01, max_depth=16, reg_lambda=0.5, subsample=0.8;, score=(train=0.758, test=0.268) total time=   6.5s
# [CV 4/5] END booster=dart, eta=0.01, max_depth=16, reg_lambda=0.5, subsample=0.8;, score=(train=0.748, test=0.472) total time=   6.6s
# [CV 5/5] END booster=dart, eta=0.01, max_depth=16, reg_lambda=0.5, subsample=0.8;, score=(train=0.748, test=0.355) total time=   7.7s
# [CV 1/5] END booster=dart, eta=0.01, max_depth=16, reg_lambda=0.5, subsample=0.9;, score=(train=0.802, test=0.043) total time=   8.2s
# [CV 2/5] END booster=dart, eta=0.01, max_depth=16, reg_lambda=0.5, subsample=0.9;, score=(train=0.791, test=0.115) total time=   8.1s
# [CV 3/5] END booster=dart, eta=0.01, max_depth=16, reg_lambda=0.5, subsample=0.9;, score=(train=0.777, test=0.257) total time=   7.7s
# [CV 4/5] END booster=dart, eta=0.01, max_depth=16, reg_lambda=0.5, subsample=0.9;, score=(train=0.769, test=0.444) total time=   7.7s
# [CV 5/5] END booster=dart, eta=0.01, max_depth=16, reg_lambda=0.5, subsample=0.9;, score=(train=0.769, test=0.321) total time=   8.4s
# [CV 1/5] END booster=dart, eta=0.01, max_depth=16, reg_lambda=0.5, subsample=1;, score=(train=0.815, test=0.055) total time=   7.6s
# [CV 2/5] END booster=dart, eta=0.01, max_depth=16, reg_lambda=0.5, subsample=1;, score=(train=0.808, test=0.052) total time=   6.8s
# [CV 3/5] END booster=dart, eta=0.01, max_depth=16, reg_lambda=0.5, subsample=1;, score=(train=0.792, test=0.260) total time=   6.6s
# [CV 4/5] END booster=dart, eta=0.01, max_depth=16, reg_lambda=0.5, subsample=1;, score=(train=0.787, test=0.457) total time=   6.7s
# [CV 5/5] END booster=dart, eta=0.01, max_depth=16, reg_lambda=0.5, subsample=1;, score=(train=0.786, test=0.282) total time=   7.3s
# [CV 1/5] END booster=dart, eta=0.01, max_depth=16, reg_lambda=0.75, subsample=0.8;, score=(train=0.777, test=-0.014) total time=   7.5s
# [CV 2/5] END booster=dart, eta=0.01, max_depth=16, reg_lambda=0.75, subsample=0.8;, score=(train=0.763, test=0.122) total time=   7.7s
# [CV 3/5] END booster=dart, eta=0.01, max_depth=16, reg_lambda=0.75, subsample=0.8;, score=(train=0.748, test=0.259) total time=   8.7s
# [CV 4/5] END booster=dart, eta=0.01, max_depth=16, reg_lambda=0.75, subsample=0.8;, score=(train=0.738, test=0.465) total time=   6.5s
# [CV 5/5] END booster=dart, eta=0.01, max_depth=16, reg_lambda=0.75, subsample=0.8;, score=(train=0.738, test=0.335) total time=   6.3s
# [CV 1/5] END booster=dart, eta=0.01, max_depth=16, reg_lambda=0.75, subsample=0.9;, score=(train=0.793, test=0.031) total time=   6.8s
# [CV 2/5] END booster=dart, eta=0.01, max_depth=16, reg_lambda=0.75, subsample=0.9;, score=(train=0.782, test=0.106) total time=   6.4s
# [CV 3/5] END booster=dart, eta=0.01, max_depth=16, reg_lambda=0.75, subsample=0.9;, score=(train=0.767, test=0.257) total time=   6.8s
# [CV 4/5] END booster=dart, eta=0.01, max_depth=16, reg_lambda=0.75, subsample=0.9;, score=(train=0.758, test=0.453) total time=   6.4s
# [CV 5/5] END booster=dart, eta=0.01, max_depth=16, reg_lambda=0.75, subsample=0.9;, score=(train=0.758, test=0.314) total time=   6.5s
# [CV 1/5] END booster=dart, eta=0.01, max_depth=16, reg_lambda=0.75, subsample=1;, score=(train=0.807, test=0.118) total time=   6.9s
# [CV 2/5] END booster=dart, eta=0.01, max_depth=16, reg_lambda=0.75, subsample=1;, score=(train=0.800, test=0.062) total time=   6.7s
# [CV 3/5] END booster=dart, eta=0.01, max_depth=16, reg_lambda=0.75, subsample=1;, score=(train=0.783, test=0.257) total time=   6.9s
# [CV 4/5] END booster=dart, eta=0.01, max_depth=16, reg_lambda=0.75, subsample=1;, score=(train=0.777, test=0.459) total time=   6.6s
# [CV 5/5] END booster=dart, eta=0.01, max_depth=16, reg_lambda=0.75, subsample=1;, score=(train=0.777, test=0.289) total time=   7.0s
# [CV 1/5] END booster=dart, eta=0.01, max_depth=16, reg_lambda=1.0, subsample=0.8;, score=(train=0.770, test=-0.029) total time=   6.6s
# [CV 2/5] END booster=dart, eta=0.01, max_depth=16, reg_lambda=1.0, subsample=0.8;, score=(train=0.754, test=0.118) total time=   6.4s
# [CV 3/5] END booster=dart, eta=0.01, max_depth=16, reg_lambda=1.0, subsample=0.8;, score=(train=0.740, test=0.258) total time=   7.3s
# [CV 4/5] END booster=dart, eta=0.01, max_depth=16, reg_lambda=1.0, subsample=0.8;, score=(train=0.729, test=0.467) total time=   7.6s
# [CV 5/5] END booster=dart, eta=0.01, max_depth=16, reg_lambda=1.0, subsample=0.8;, score=(train=0.729, test=0.324) total time=   7.1s
# [CV 1/5] END booster=dart, eta=0.01, max_depth=16, reg_lambda=1.0, subsample=0.9;, score=(train=0.786, test=0.006) total time=   7.8s
# [CV 2/5] END booster=dart, eta=0.01, max_depth=16, reg_lambda=1.0, subsample=0.9;, score=(train=0.773, test=0.097) total time=   6.8s
# [CV 3/5] END booster=dart, eta=0.01, max_depth=16, reg_lambda=1.0, subsample=0.9;, score=(train=0.759, test=0.262) total time=   7.9s
# [CV 4/5] END booster=dart, eta=0.01, max_depth=16, reg_lambda=1.0, subsample=0.9;, score=(train=0.750, test=0.465) total time=   7.2s
# [CV 5/5] END booster=dart, eta=0.01, max_depth=16, reg_lambda=1.0, subsample=0.9;, score=(train=0.751, test=0.296) total time=   6.3s
# [CV 1/5] END booster=dart, eta=0.01, max_depth=16, reg_lambda=1.0, subsample=1;, score=(train=0.800, test=0.082) total time=   8.3s
# [CV 2/5] END booster=dart, eta=0.01, max_depth=16, reg_lambda=1.0, subsample=1;, score=(train=0.793, test=0.060) total time=   8.2s
# [CV 3/5] END booster=dart, eta=0.01, max_depth=16, reg_lambda=1.0, subsample=1;, score=(train=0.775, test=0.268) total time=   7.8s
# [CV 4/5] END booster=dart, eta=0.01, max_depth=16, reg_lambda=1.0, subsample=1;, score=(train=0.769, test=0.398) total time=   7.7s
# [CV 5/5] END booster=dart, eta=0.01, max_depth=16, reg_lambda=1.0, subsample=1;, score=(train=0.769, test=0.275) total time=   7.3s
# GridSearchCV(cv=5,
#              estimator=XGBRegressor(base_score=None, booster=None,
#                                     callbacks=None, colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None,
#                                     early_stopping_rounds=None,
#                                     enable_categorical=True, eval_metric=None,
#                                     feature_types=None, gamma=None, gpu_id=None,
#                                     grow_policy=None, importance_type=None,
#                                     interaction_constraints=None,
#                                     learning_rate=None, ma...
#                                     max_depth=None, max_leaves=None,
#                                     min_child_weight=None, missing=nan,
#                                     monotone_constraints=None, n_estimators=100,
#                                     n_jobs=None, num_parallel_tree=None,
#                                     predictor=None, random_state=None, ...),
#              param_grid={'booster': ['gbtree', 'dart'],
#                          'eta': [0.1, 0.05, 0.01],
#                          'max_depth': array([14, 15, 16]),
#                          'reg_lambda': array([0.5 , 0.75, 1.  ]),
#                          'subsample': [0.8, 0.9, 1]},
#              return_train_score=True, verbose=3)

# %%
print(f'best hyperparameters are: {grid.best_params_} with the accuracy of: {grid.best_score_:.2f}')
# Out:
# best hyperparameters are: {'booster': 'dart', 'eta': 0.1, 'max_depth': 16, 'reg_lambda': 0.5, 'subsample': 0.8} with the accuracy of: 0.45

# %% [markdown]
# The optimised hyperparameters for the model is:
# - **Booster**: dart
# - **ETA**: 0.1
# - **Max Depth**: 16
# - **Regularization Lambda**: 0.5
# - **Subsample**: 0.8
#
# Now that we have the optimsed hyperparameters, we can train the model with training dataset and asses it with validation set
#
# Another fact to have in mind is the objective in use. We will use squared error as objective of this model, since this metric is more prone to the outliers.

# %%
model = xgb.XGBRegressor(tree_method='hist', enable_categorical=True, booster='dart', learning_rate=.1, max_depth=16, reg_lambda=.5, subsample=.8, objective='reg:squarederror', )

model.fit(X_train, y_train)
print(f'Model Score: {model.score(X_test, y_test):.2f}')
# Out:
# Model Score: 0.51

# %% [markdown]
# In the cell above you can see the Score of the model trained on the train dataset and validated on the validation dataset. Interesting feature that can be see here, is that model resulted in more accurate than the cross validation average. This means the model has high variance. Although we have used regularization to reduce the variance, but the best and main approach to reduce the variance is to collect more data for training. Since this approach is time-consuming and is out of the scope of the competition, we won't scrape the Instagram data further.

# %%
feature_importances = {
    key:f'{value:.8f}' for key,value in zip(X.columns, model.feature_importances_)
}
feature_importances = sorted(feature_importances.items(), key=lambda x:x[1], reverse=True)
feature_importances
# Out:
# [('media_avg_like', '0.93177462'),
#  ('type_professional', '0.01981526'),
#  ('object', '0.01431775'),
#  ('media_avg_comment', '0.00830188'),
#  ('media_count', '0.00524774'),
#  ('reel_frequency', '0.00286807'),
#  ('reel_avg_like', '0.00239714'),
#  ('media_frequency', '0.00194521'),
#  ('reel_avg_view', '0.00192337'),
#  ('category_name', '0.00177285'),
#  ('follower', '0.00176363'),
#  ('reel_avg_comment', '0.00158892'),
#  ('reel_avg_duration', '0.00153614'),
#  ('ar_effect', '0.00137711'),
#  ('following', '0.00112187'),
#  ('reel_count', '0.00106014'),
#  ('post_type', '0.00066400'),
#  ('type_business', '0.00052189'),
#  ('verified', '0.00000245')]

# %% [markdown]
# As you can see in the table above, the most important feature on our dataset based on the trained model, is the **posts average like** by the huge margins. The content of the posted is the third most important feature based on this model. Since the difference between the importances is huge, We omit the media_avg_like and plot the other features in the graph below.

# %%
num_features = len(X.columns) - 1
fig = plt.figure(figsize=(10, 5 * num_features // 10))
temp_x = [float(x[1]) for x in feature_importances]
temp_x.remove(temp_x[0])
temp_y = [x[0] for x in feature_importances]
temp_y.remove(temp_y[0])
ax = sns.barplot(x=temp_x, y=temp_y)
ax.bar_label(ax.containers[0])
plt.title('Feature importances without the most important feature (Media_avg_like)')
plt.show()

# %% [markdown]
# Now that we have the information needed, before saving the model and using it as predictive model, we will train the model with all of the data, then saving it. Please have in mind that since the model is using categorical data, it's suggested to save it as a json file.

# %%
model.fit(X, y)
# Out:
# XGBRegressor(base_score=None, booster='dart', callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=True, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.1, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=16, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)

# %%
model.save_model('Models/xgb v2.0.json')

# %% [markdown]
# Now that we have the working model we will prepare the pipeline and use it as an operation.

# %% [markdown]
# ----
# `@Ramin F.` | [Email](ferdos.ramin@gmail.com) | [LinkedIn](https://www.linkedin.com/in/raminferdos/) | [GitHub](https://github.com/SimplyRamin) | [Personal Portfolio](https://simplyramin.github.io/)
